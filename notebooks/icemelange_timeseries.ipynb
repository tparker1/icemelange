# %% [markdown]
# # Ice Mélange timeseries for Disko Bay, GL

# %% [markdown]
# Created using the [] tutorial at []

# %%
import rioxarray
#import os
#os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pyproj import CRS, Proj, transform, Transformer
from sliderule import sliderule, icesat2, earthdata, h5
from scipy.interpolate import RectBivariateSpline
from shapely import wkt

# Fancier plotting tools
from cartopy import crs
import geoviews as gv
import geoviews.feature as gf
from geoviews import dim, opts
import geoviews.tile_sources as gts
from bokeh.models import HoverTool
gv.extension('bokeh')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# ## Initialize SlideRule

# %%
# Initialize SlideRule
icesat2.init("slideruleearth.io")

# %% [markdown]
# ## Define Region of Interest

# %%
# path to geoJSON polygon
geoJSON_filepath = '/home/jovyan/tutorial/Jakobshavn_GJSON.geojson'
region = sliderule.toregion(geoJSON_filepath)["poly"]

region
# Out:
# [{'lon': -49.97808766660942, 'lat': 69.10465143509425},
#  {'lon': -49.8912305265689, 'lat': 69.10998685551378},
#  {'lon': -49.836091930293584, 'lat': 69.11830731021058},
#  {'lon': -49.80086524211196, 'lat': 69.1322155296216},
#  {'lon': -49.80118597640616, 'lat': 69.13885210573721},
#  {'lon': -49.807842686182866, 'lat': 69.17232907798441},
#  {'lon': -49.82969708328032, 'lat': 69.2066839228936},
#  {'lon': -49.87473310757, 'lat': 69.21241716452107},
#  {'lon': -49.994611426671085, 'lat': 69.21273016310525},
#  {'lon': -50.09052139047812, 'lat': 69.21194082687681},
#  {'lon': -51.160830490256444, 'lat': 69.19844218768367},
#  {'lon': -51.215226113975355, 'lat': 69.18834999781578},
#  {'lon': -51.21722962356639, 'lat': 69.174502224272},
#  {'lon': -51.20775815803788, 'lat': 69.15576981382578},
#  {'lon': -51.18136072158214, 'lat': 69.1345841627497},
#  {'lon': -50.94203963265182, 'lat': 69.12544171588522},
#  {'lon': -49.97808766660942, 'lat': 69.10465143509425}]

# %% [markdown]
# ## Build SlideRule Request

# %% [markdown]
# More information can be found in the [SlideRule users guide](https://slideruleearth.io/web/rtd/user_guide/ICESat-2.html#parameters).
#
# ```{note} **Parameters**
# * `poly`: polygon defining region of interest
# * `track`: reference pair track number (1, 2, 3, or 0 to include for all three; defaults to 0)
# * `rgt`: reference ground track (defaults to all if not specified)
# * `cycle`: counter of 91-day repeat cycles completed by the mission (defaults to all if not specified)
# * `region`: geographic region for corresponding standard product (defaults to all if not specified)
# * `t0`: start time for filtering granules (format %Y-%m-%dT%H:%M:%SZ, e.g. 2018-10-13T00:00:00Z)
# * `t1`: stop time for filtering granuels (format %Y-%m-%dT%H:%M:%SZ, e.g. 2018-10-13T00:00:00Z)
# * `srt`: surface type: 0-land, 1-ocean, 2-sea ice, 3-land ice, 4-inland water
# * `cnf`: confidence level for photon selection, can be supplied as a single value (which means the confidence must be at least that), or a list (which means the confidence must be in the list)
# * `atl08_class`: list of ATL08 classifications used to select which photons are used in the processing (the available classifications are: “atl08_noise”, “atl08_ground”, “atl08_canopy”, “atl08_top_of_canopy”, “atl08_unclassified”)
# * `maxi`: maximum iterations, not including initial least-squares-fit selection
# * `H_min_win`: minimum height to which the refined photon-selection window is allowed to shrink, in meters
# * `sigma_r_max`: maximum robust dispersion in meters
# * `compact`: return compact version of results (leaves out most metadata)
# ```

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region,
    "srt": icesat2.SRT_LAND,
    "cnf": [icesat2.CNF_SURFACE_HIGH,icesat2.CNF_SURFACE_MEDIUM],
    "atl08_class": ["atl08_ground"],
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df = icesat2.atl06p(parms, "nsidc-s3")

#Remove outlier data
is2_df= is2_df[is2_df['h_mean'] < 175]

# Display top of the ICESat-2 dataframe
is2_df.head()
# Out:
#                                   h_mean  dh_fit_dx  w_surface_window_final  \
# time
# 2018-10-17 07:07:12.597756416  26.943918   0.000900                     3.0
# 2018-10-17 07:07:12.599166208  27.026660   0.034994                     3.0
# 2018-10-17 07:07:12.600574208  27.218592   0.026768                     3.0
# 2018-10-17 07:07:12.601983744  27.560845   0.048706                     3.0
# 2018-10-17 07:07:12.603391488  28.101927   0.056609                     3.0
#
#                                rms_misfit  cycle  pflags      distance  spot  \
# time
# 2018-10-17 07:07:12.597756416    0.272474      1       0  1.235138e+07     6
# 2018-10-17 07:07:12.599166208    0.278298      1       0  1.235139e+07     6
# 2018-10-17 07:07:12.600574208    0.248496      1       0  1.235140e+07     6
# 2018-10-17 07:07:12.601983744    0.228534      1       0  1.235141e+07     6
# 2018-10-17 07:07:12.603391488    0.251437      1       0  1.235142e+07     6
#
#                                n_fit_photons  dh_fit_dy   h_sigma  gt  rgt  \
# time
# 2018-10-17 07:07:12.597756416             17        0.0  0.070805  10  285
# 2018-10-17 07:07:12.599166208             24        0.0  0.059368  10  285
# 2018-10-17 07:07:12.600574208             38        0.0  0.041451  10  285
# 2018-10-17 07:07:12.601983744             53        0.0  0.031394  10  285
# 2018-10-17 07:07:12.603391488             31        0.0  0.071598  10  285
#
#                                segment_id                    geometry
# time
# 2018-10-17 07:07:12.597756416      616651  POINT (-49.93051 69.21196)
# 2018-10-17 07:07:12.599166208      616652  POINT (-49.93055 69.21187)
# 2018-10-17 07:07:12.600574208      616652  POINT (-49.93058 69.21178)
# 2018-10-17 07:07:12.601983744      616653  POINT (-49.93061 69.21169)
# 2018-10-17 07:07:12.603391488      616653  POINT (-49.93064 69.21160)

# %% [markdown]
# ## Visualize all of the ICESat-2 tracks since its launch within the region of interest

# %%
# # Visualize all of the ICESat-2 tracks since its launch within the region of interest

# # Calculate Extent
# lons = [p["lon"] for p in region]
# lats = [p["lat"] for p in region]
# lon_margin = (max(lons) - min(lons)) * 0.1
# lat_margin = (max(lats) - min(lats)) * 0.1

# # Create Plot
# fig, ax1 = plt.subplots(num=None, ncols=1, figsize=(12, 6))
# box_lon = [e["lon"] for e in region]
# box_lat = [e["lat"] for e in region]

# # Plot SlideRule Ground Tracks
# ax1.set_title("SlideRule Zoomed Ground Tracks")
# ROI = is2_df.plot(ax=ax1, column=is2_df["h_mean"], cmap='winter_r', s=1.0, zorder=3)
# ax1.plot(box_lon, box_lat, linewidth=1.5, color='r', zorder=2)
# ax1.set_xlim(min(lons) - lon_margin, max(lons) + lon_margin)
# ax1.set_ylim(min(lats) - lat_margin, max(lats) + lat_margin)
# ax1.set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Plot Time Series

# %%
# Add a date column to the data frame so we can group the data by day 

# get the timestamps from the dataframe index
timestamps = is2_df.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df['day'] = time

# print the head of the data frame
is2_df.head()
# Out:
#                                   h_mean  dh_fit_dx  w_surface_window_final  \
# time
# 2018-10-17 07:07:12.597756416  26.943918   0.000900                     3.0
# 2018-10-17 07:07:12.599166208  27.026660   0.034994                     3.0
# 2018-10-17 07:07:12.600574208  27.218592   0.026768                     3.0
# 2018-10-17 07:07:12.601983744  27.560845   0.048706                     3.0
# 2018-10-17 07:07:12.603391488  28.101927   0.056609                     3.0
#
#                                rms_misfit  cycle  pflags      distance  spot  \
# time
# 2018-10-17 07:07:12.597756416    0.272474      1       0  1.235138e+07     6
# 2018-10-17 07:07:12.599166208    0.278298      1       0  1.235139e+07     6
# 2018-10-17 07:07:12.600574208    0.248496      1       0  1.235140e+07     6
# 2018-10-17 07:07:12.601983744    0.228534      1       0  1.235141e+07     6
# 2018-10-17 07:07:12.603391488    0.251437      1       0  1.235142e+07     6
#
#                                n_fit_photons  dh_fit_dy   h_sigma  gt  rgt  \
# time
# 2018-10-17 07:07:12.597756416             17        0.0  0.070805  10  285
# 2018-10-17 07:07:12.599166208             24        0.0  0.059368  10  285
# 2018-10-17 07:07:12.600574208             38        0.0  0.041451  10  285
# 2018-10-17 07:07:12.601983744             53        0.0  0.031394  10  285
# 2018-10-17 07:07:12.603391488             31        0.0  0.071598  10  285
#
#                                segment_id                    geometry  \
# time
# 2018-10-17 07:07:12.597756416      616651  POINT (-49.93051 69.21196)
# 2018-10-17 07:07:12.599166208      616652  POINT (-49.93055 69.21187)
# 2018-10-17 07:07:12.600574208      616652  POINT (-49.93058 69.21178)
# 2018-10-17 07:07:12.601983744      616653  POINT (-49.93061 69.21169)
# 2018-10-17 07:07:12.603391488      616653  POINT (-49.93064 69.21160)
#
#                                       day
# time
# 2018-10-17 07:07:12.597756416  2018-10-17
# 2018-10-17 07:07:12.599166208  2018-10-17
# 2018-10-17 07:07:12.600574208  2018-10-17
# 2018-10-17 07:07:12.601983744  2018-10-17
# 2018-10-17 07:07:12.603391488  2018-10-17

# %%
#%matplotlib widget
fig, ax = plt.subplots(figsize=(20, 6))

plt.plot(is2_df.groupby(['day']).mean()['h_mean'])

plt.xticks(rotation=90)

plt.show()
# Out:
# /tmp/ipykernel_1268/1556553341.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# # Create Regional Time Series for Fjord

# %%
# %pwd
# Out:
# '/home/jovyan/hackweek2023/icemelange/notebooks'

# %% [markdown]
# ## East Region

# %%
# path to geoJSON polygon

# East Fjord
geoJSON_filepath = '/home/jovyan/hackweek2023/icemelange/data/gjsons/Jakobshavn_east.geojson'
region_ea = sliderule.toregion(geoJSON_filepath)["poly"]

print("East Polygon: ")
print(region_ea)
# Out:
# East Polygon:
# [{'lon': -49.989773275146256, 'lat': 69.10200477899474}, {'lon': -49.90158875862826, 'lat': 69.10809774274587}, {'lon': -49.84117027276759, 'lat': 69.11599894849657}, {'lon': -49.79205503389916, 'lat': 69.13600213474544}, {'lon': -49.79174593359926, 'lat': 69.13870624159743}, {'lon': -49.78672414740628, 'lat': 69.19376869249525}, {'lon': -49.78877398600027, 'lat': 69.2024675890045}, {'lon': -49.796786456519094, 'lat': 69.20829362263899}, {'lon': -49.81101051505902, 'lat': 69.2162925752355}, {'lon': -50.13225888314705, 'lat': 69.21445631807542}, {'lon': -50.17265806975064, 'lat': 69.21282531891303}, {'lon': -50.20697408838873, 'lat': 69.20969529529557}, {'lon': -50.20594500512282, 'lat': 69.20568286621973}, {'lon': -50.192089853856494, 'lat': 69.17005925050293}, {'lon': -50.18586112928695, 'lat': 69.15677702804891}, {'lon': -50.010508466555606, 'lat': 69.10573723906185}, {'lon': -49.989773275146256, 'lat': 69.10200477899474}]

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region_ea,
    "srt": icesat2.SRT_LAND,
    "cnf": [icesat2.CNF_SURFACE_HIGH,icesat2.CNF_SURFACE_MEDIUM],
    "atl08_class": ["atl08_ground"],
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df_ea = icesat2.atl06p(parms, "nsidc-s3")

#Remove outlier data
is2_df_ea = is2_df_ea[is2_df_ea['h_mean'] < 175]

# %%
# # Visualize all of the ICESat-2 tracks since its launch within the region of interest

# # Calculate Extent
# lons = [p["lon"] for p in region_ea]
# lats = [p["lat"] for p in region_ea]
# lon_margin = (max(lons) - min(lons)) * 0.1
# lat_margin = (max(lats) - min(lats)) * 0.1

# # Create Plot
# fig, ax1 = plt.subplots(num=None, ncols=1, figsize=(12, 6))
# box_lon = [e["lon"] for e in region_ea]
# box_lat = [e["lat"] for e in region_ea]

# # Plot SlideRule Ground Tracks
# ax1.set_title("SlideRule Zoomed Ground Tracks")
# ROI = is2_df.plot(ax=ax1, column=is2_df_ea["h_mean"], cmap='winter_r', s=1.0, zorder=3)
# ax1.plot(box_lon, box_lat, linewidth=1.5, color='r', zorder=2)
# ax1.set_xlim(min(lons) - lon_margin, max(lons) + lon_margin)
# ax1.set_ylim(min(lats) - lat_margin, max(lats) + lat_margin)
# ax1.set_aspect('equal', adjustable='box')

# %%
# Add a date column to the data frame so we can group the data by day 
# get the timestamps from the dataframe index
timestamps = is2_df_ea.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df_ea['day'] = time

# print the head of the data frame
is2_df_ea.head()
# Out:
#                                   h_mean  dh_fit_dx  w_surface_window_final  \
# time
# 2018-10-17 07:07:12.541339136  91.368098  -0.262022                6.709494
# 2018-10-17 07:07:12.542747136  88.604906  -0.324920                8.307998
# 2018-10-17 07:07:12.544155648  85.244381  -0.365870                9.349710
# 2018-10-17 07:07:12.545565440  81.682674  -0.328074                8.388207
# 2018-10-17 07:07:12.546973184  78.529500  -0.274983                7.038696
#
#                                rms_misfit  cycle  pflags      distance  spot  \
# time
# 2018-10-17 07:07:12.541339136    0.426336      1       0  1.235098e+07     6
# 2018-10-17 07:07:12.542747136    0.462423      1       0  1.235099e+07     6
# 2018-10-17 07:07:12.544155648    0.505713      1       0  1.235100e+07     6
# 2018-10-17 07:07:12.545565440    0.572686      1       0  1.235101e+07     6
# 2018-10-17 07:07:12.546973184    0.494804      1       0  1.235102e+07     6
#
#                                n_fit_photons  dh_fit_dy   h_sigma  gt  rgt  \
# time
# 2018-10-17 07:07:12.541339136             18        0.0  0.101441  10  285
# 2018-10-17 07:07:12.542747136             20        0.0  0.106666  10  285
# 2018-10-17 07:07:12.544155648             15        0.0  0.135315  10  285
# 2018-10-17 07:07:12.545565440             11        0.0  0.172675  10  285
# 2018-10-17 07:07:12.546973184             14        0.0  0.135776  10  285
#
#                                segment_id                    geometry  \
# time
# 2018-10-17 07:07:12.541339136      616631  POINT (-49.92930 69.21552)
# 2018-10-17 07:07:12.542747136      616632  POINT (-49.92933 69.21543)
# 2018-10-17 07:07:12.544155648      616632  POINT (-49.92936 69.21534)
# 2018-10-17 07:07:12.545565440      616633  POINT (-49.92939 69.21525)
# 2018-10-17 07:07:12.546973184      616633  POINT (-49.92942 69.21517)
#
#                                       day
# time
# 2018-10-17 07:07:12.541339136  2018-10-17
# 2018-10-17 07:07:12.542747136  2018-10-17
# 2018-10-17 07:07:12.544155648  2018-10-17
# 2018-10-17 07:07:12.545565440  2018-10-17
# 2018-10-17 07:07:12.546973184  2018-10-17

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(is2_df_ea.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_1268/814862716.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_ea.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# ## Center Region

# %%
# path to geoJSON polygon

# East Fjord
geoJSON_filepath = '/home/jovyan/hackweek2023/icemelange/data/gjsons/Jakobshavn_mid.geojson'
region_ce = sliderule.toregion(geoJSON_filepath)["poly"]

print("Center Polygon: ")
print(region_ce)
# Out:
# Center Polygon:
# [{'lon': -50.52268667277289, 'lat': 69.12799535794046}, {'lon': -50.4159006861964, 'lat': 69.12826920366282}, {'lon': -50.269682636213254, 'lat': 69.13685284157046}, {'lon': -50.244026354810224, 'lat': 69.14005389024756}, {'lon': -50.205146130839864, 'lat': 69.15075914207608}, {'lon': -50.193030289148666, 'lat': 69.15519681821438}, {'lon': -50.20602440962679, 'lat': 69.19489189788993}, {'lon': -50.21432839774787, 'lat': 69.20507409846321}, {'lon': -50.220834170670855, 'lat': 69.20823452277214}, {'lon': -50.58184111126958, 'lat': 69.20926087844283}, {'lon': -50.673441144883405, 'lat': 69.20740368535955}, {'lon': -50.76123002594027, 'lat': 69.19213255719504}, {'lon': -50.78094807061578, 'lat': 69.18804949884753}, {'lon': -50.72876131151459, 'lat': 69.13424997330652}, {'lon': -50.689414409692105, 'lat': 69.12890545159506}, {'lon': -50.52268667277289, 'lat': 69.12799535794046}]

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region_ce,
    "srt": icesat2.SRT_LAND,
    "cnf": [icesat2.CNF_SURFACE_HIGH,icesat2.CNF_SURFACE_MEDIUM],
    "atl08_class": ["atl08_ground"],
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df_ce = icesat2.atl06p(parms, "nsidc-s3")

#Remove outlier data
is2_df_ce = is2_df_ce[is2_df_ce['h_mean'] < 175]

# %%
# Add a date column to the data frame so we can group the data by day 
# get the timestamps from the dataframe index
timestamps = is2_df_ce.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df_ce['day'] = time

# print the head of the data frame
is2_df_ce.head()
# Out:
#                                   h_mean  dh_fit_dx  w_surface_window_final  \
# time
# 2018-10-24 18:05:24.077861376  24.898022   0.021906                     3.0
# 2018-10-24 18:05:24.078302208  25.262475   0.004026                     3.0
# 2018-10-24 18:05:24.079272960  24.962811  -0.017065                     3.0
# 2018-10-24 18:05:24.079713792  25.246657  -0.002402                     3.0
# 2018-10-24 18:05:24.080686080  24.880956   0.001833                     3.0
#
#                                rms_misfit  cycle  pflags      distance  spot  \
# time
# 2018-10-24 18:05:24.077861376    0.208628      1       0  7.710284e+06     6
# 2018-10-24 18:05:24.078302208    0.121202      1       0  7.710495e+06     2
# 2018-10-24 18:05:24.079272960    0.177127      1       0  7.710294e+06     6
# 2018-10-24 18:05:24.079713792    0.128890      1       0  7.710505e+06     2
# 2018-10-24 18:05:24.080686080    0.163453      1       0  7.710304e+06     6
#
#                                n_fit_photons  dh_fit_dy   h_sigma  gt  rgt  \
# time
# 2018-10-24 18:05:24.077861376             20        0.0  0.050285  10  399
# 2018-10-24 18:05:24.078302208             53        0.0  0.016661  50  399
# 2018-10-24 18:05:24.079272960             41        0.0  0.029487  10  399
# 2018-10-24 18:05:24.079713792             54        0.0  0.017544  50  399
# 2018-10-24 18:05:24.080686080             57        0.0  0.021651  10  399
#
#                                segment_id                    geometry  \
# time
# 2018-10-24 18:05:24.077861376      384684  POINT (-50.42887 69.12842)
# 2018-10-24 18:05:24.078302208      384694  POINT (-50.26752 69.13729)
# 2018-10-24 18:05:24.079272960      384684  POINT (-50.42890 69.12851)
# 2018-10-24 18:05:24.079713792      384695  POINT (-50.26755 69.13738)
# 2018-10-24 18:05:24.080686080      384685  POINT (-50.42893 69.12860)
#
#                                       day
# time
# 2018-10-24 18:05:24.077861376  2018-10-24
# 2018-10-24 18:05:24.078302208  2018-10-24
# 2018-10-24 18:05:24.079272960  2018-10-24
# 2018-10-24 18:05:24.079713792  2018-10-24
# 2018-10-24 18:05:24.080686080  2018-10-24

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_1268/184878275.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# ## West Region

# %%
# path to geoJSON polygon

# East Fjord
geoJSON_filepath = '/home/jovyan/hackweek2023/icemelange/data/gjsons/Jakobshavn_west.geojson'
region_we = sliderule.toregion(geoJSON_filepath)["poly"]

print("West Polygon: ")
print(region_we)
# Out:
# West Polygon:
# [{'lon': -50.93756706078053, 'lat': 69.12062339157777}, {'lon': -50.81636301612652, 'lat': 69.12667557985148}, {'lon': -50.801204764963416, 'lat': 69.12795382303807}, {'lon': -50.73594465283092, 'lat': 69.13554808360637}, {'lon': -50.736799954576924, 'lat': 69.14003277515364}, {'lon': -50.745848662459174, 'lat': 69.15471172484692}, {'lon': -50.754084491355634, 'lat': 69.16213682989415}, {'lon': -50.77877233377383, 'lat': 69.17989636608537}, {'lon': -50.790703937126544, 'lat': 69.18296289314115}, {'lon': -51.15064793209109, 'lat': 69.20120439226609}, {'lon': -51.161147654309275, 'lat': 69.20065612905515}, {'lon': -51.172161663652915, 'lat': 69.19775462036746}, {'lon': -51.18325690610557, 'lat': 69.18974618751375}, {'lon': -51.1831419904824, 'lat': 69.18129447853951}, {'lon': -51.17920494172613, 'lat': 69.16701301321055}, {'lon': -51.17487009831605, 'lat': 69.15814146989767}, {'lon': -51.149547444275804, 'lat': 69.1407479720041}, {'lon': -51.1315794764893, 'lat': 69.13677253859474}, {'lon': -50.95147418723264, 'lat': 69.1206896578055}, {'lon': -50.93756706078053, 'lat': 69.12062339157777}]

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region_we,
    "srt": icesat2.SRT_LAND,
    "cnf": [icesat2.CNF_SURFACE_HIGH,icesat2.CNF_SURFACE_MEDIUM],
    "atl08_class": ["atl08_ground"],
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df_we = icesat2.atl06p(parms, "nsidc-s3")

#Remove outlier data
is2_df_we = is2_df_we[is2_df_we['h_mean'] < 175]

# %%
# Add a date column to the data frame so we can group the data by day 
# get the timestamps from the dataframe index
timestamps = is2_df_we.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df_we['day'] = time

# print the head of the data frame
is2_df_we.head()
# Out:
#                                   h_mean  dh_fit_dx  w_surface_window_final  \
# time
# 2018-11-26 16:33:02.204200704  25.156895  -0.000560                     3.0
# 2018-11-26 16:33:02.205597440  25.135907  -0.001830                     3.0
# 2018-11-26 16:33:02.206994688  25.132038   0.005519                     3.0
# 2018-11-26 16:33:02.208395520  25.154071   0.002466                     3.0
# 2018-11-26 16:33:02.209792256  25.166626  -0.000497                     3.0
#
#                                rms_misfit  cycle  pflags      distance  spot  \
# time
# 2018-11-26 16:33:02.204200704    0.104498      1       0  7.709415e+06     6
# 2018-11-26 16:33:02.205597440    0.095722      1       0  7.709425e+06     6
# 2018-11-26 16:33:02.206994688    0.100977      1       0  7.709435e+06     6
# 2018-11-26 16:33:02.208395520    0.103374      1       0  7.709445e+06     6
# 2018-11-26 16:33:02.209792256    0.084554      1       0  7.709455e+06     6
#
#                                n_fit_photons  dh_fit_dy   h_sigma  gt  rgt  \
# time
# 2018-11-26 16:33:02.204200704             45        0.0  0.016452  10  902
# 2018-11-26 16:33:02.205597440             57        0.0  0.012679  10  902
# 2018-11-26 16:33:02.206994688             59        0.0  0.013256  10  902
# 2018-11-26 16:33:02.208395520             74        0.0  0.012146  10  902
# 2018-11-26 16:33:02.209792256             82        0.0  0.009337  10  902
#
#                                segment_id                    geometry  \
# time
# 2018-11-26 16:33:02.204200704      384645  POINT (-50.94503 69.12069)
# 2018-11-26 16:33:02.205597440      384646  POINT (-50.94506 69.12078)
# 2018-11-26 16:33:02.206994688      384646  POINT (-50.94509 69.12087)
# 2018-11-26 16:33:02.208395520      384647  POINT (-50.94512 69.12096)
# 2018-11-26 16:33:02.209792256      384647  POINT (-50.94515 69.12105)
#
#                                       day
# time
# 2018-11-26 16:33:02.204200704  2018-11-26
# 2018-11-26 16:33:02.205597440  2018-11-26
# 2018-11-26 16:33:02.206994688  2018-11-26
# 2018-11-26 16:33:02.208395520  2018-11-26
# 2018-11-26 16:33:02.209792256  2018-11-26

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(is2_df_we.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_1268/1376355974.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_we.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# # Show plots again to compare

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(is2_df_ea.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_1268/814862716.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_ea.groupby(['day']).mean()['h_mean'])

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_1268/184878275.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(is2_df_we.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_1268/1376355974.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_we.groupby(['day']).mean()['h_mean'])

# %%
fig, ax1, ax2, ax3 = plt.subplots(figsize=(20, 6))
