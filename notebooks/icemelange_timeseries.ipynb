# %% [markdown]
# # Ice Mélange timeseries for Disko Bay, GL

# %% [markdown]
# Created using the [] tutorial at []

# %%
import rioxarray
#import os
#os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pyproj import CRS, Proj, transform, Transformer
from sliderule import sliderule, icesat2, earthdata, h5
from scipy.interpolate import RectBivariateSpline
from shapely import wkt

# Fancier plotting tools
from cartopy import crs
import geoviews as gv
import geoviews.feature as gf
from geoviews import dim, opts
import geoviews.tile_sources as gts
from bokeh.models import HoverTool
gv.extension('bokeh')
# Out:
# /tmp/ipykernel_3055/1588569292.py:4: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /srv/conda/envs/notebook/lib/python3.10/site-packages/geoviews/operation/__init__.py:14: HoloviewsDeprecationWarning: 'ResamplingOperation' is deprecated and will be removed in version 1.18, use 'ResampleOperation2D' instead.
#   from holoviews.operation.datashader import (
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
#%pip install --upgrade scipy
#%pip install pyTMD

# %% [markdown]
# ## Initialize SlideRule

# %%
# Initialize SlideRule
icesat2.init("slideruleearth.io")

# %% [markdown]
# ## Define Region of Interest
# ### Full-length of Jakobshavn Fjord

# %%
# path to geoJSON polygon
geoJSON_filepath = '/home/jovyan/tutorial/Jakobshavn_GJSON.geojson'
region = sliderule.toregion(geoJSON_filepath)["poly"]

region
# Out:
# [{'lon': -49.97808766660942, 'lat': 69.10465143509425},
#  {'lon': -49.8912305265689, 'lat': 69.10998685551378},
#  {'lon': -49.836091930293584, 'lat': 69.11830731021058},
#  {'lon': -49.80086524211196, 'lat': 69.1322155296216},
#  {'lon': -49.80118597640616, 'lat': 69.13885210573721},
#  {'lon': -49.807842686182866, 'lat': 69.17232907798441},
#  {'lon': -49.82969708328032, 'lat': 69.2066839228936},
#  {'lon': -49.87473310757, 'lat': 69.21241716452107},
#  {'lon': -49.994611426671085, 'lat': 69.21273016310525},
#  {'lon': -50.09052139047812, 'lat': 69.21194082687681},
#  {'lon': -51.160830490256444, 'lat': 69.19844218768367},
#  {'lon': -51.215226113975355, 'lat': 69.18834999781578},
#  {'lon': -51.21722962356639, 'lat': 69.174502224272},
#  {'lon': -51.20775815803788, 'lat': 69.15576981382578},
#  {'lon': -51.18136072158214, 'lat': 69.1345841627497},
#  {'lon': -50.94203963265182, 'lat': 69.12544171588522},
#  {'lon': -49.97808766660942, 'lat': 69.10465143509425}]

# %% [markdown]
# ## Build SlideRule Request

# %% [markdown]
# More information can be found in the [SlideRule users guide](https://slideruleearth.io/web/rtd/user_guide/ICESat-2.html#parameters).
#
# ```{note} **Parameters**
# * `poly`: polygon defining region of interest
# * `track`: reference pair track number (1, 2, 3, or 0 to include for all three; defaults to 0)
# * `rgt`: reference ground track (defaults to all if not specified)
# * `cycle`: counter of 91-day repeat cycles completed by the mission (defaults to all if not specified)
# * `region`: geographic region for corresponding standard product (defaults to all if not specified)
# * `t0`: start time for filtering granules (format %Y-%m-%dT%H:%M:%SZ, e.g. 2018-10-13T00:00:00Z)
# * `t1`: stop time for filtering granuels (format %Y-%m-%dT%H:%M:%SZ, e.g. 2018-10-13T00:00:00Z)
# * `srt`: surface type: 0-land, 1-ocean, 2-sea ice, 3-land ice, 4-inland water
# * `cnf`: confidence level for photon selection, can be supplied as a single value (which means the confidence must be at least that), or a list (which means the confidence must be in the list)
# * `atl08_class`: list of ATL08 classifications used to select which photons are used in the processing (the available classifications are: “atl08_noise”, “atl08_ground”, “atl08_canopy”, “atl08_top_of_canopy”, “atl08_unclassified”)
# * `maxi`: maximum iterations, not including initial least-squares-fit selection
# * `H_min_win`: minimum height to which the refined photon-selection window is allowed to shrink, in meters
# * `sigma_r_max`: maximum robust dispersion in meters
# * `compact`: return compact version of results (leaves out most metadata)
# ```

# %% [markdown]
# ## Jakobshavn Fjord - Total

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region,
    "srt": icesat2.SRT_SEA_ICE,
    "cnf": icesat2.CNF_SURFACE_HIGH,
    #"atl08_class": ["atl08_ground"],
    #"cnf": 0,
    #"yapc": { "score": 10, "knn": 0 },
    "ats": 5.0,
    "len": 20.0,
    "res": 20.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df = icesat2.atl06p(parms, "nsidc-s3")

# Display top of the ICESat-2 dataframe
is2_df.head()
# Out:
#                                   h_mean  dh_fit_dx  pflags  dh_fit_dy  cycle  \
# time
# 2018-10-24 18:05:23.758083840  99.706509  -0.047784       0        0.0      1
# 2018-10-24 18:05:23.760899840  98.420755  -0.077792       0        0.0      1
# 2018-10-24 18:05:23.763715840  97.483013  -0.005488       0        0.0      1
# 2018-10-24 18:05:23.766530304  97.323345  -0.014183       0        0.0      1
# 2018-10-24 18:05:23.769344000  97.314007   0.023980       0        0.0      1
#
#                                rms_misfit   h_sigma  gt  segment_id  spot  \
# time
# 2018-10-24 18:05:23.758083840    0.298873  0.045156  30      384575     4
# 2018-10-24 18:05:23.760899840    0.380302  0.052739  30      384576     4
# 2018-10-24 18:05:23.763715840    0.258524  0.037528  30      384577     4
# 2018-10-24 18:05:23.766530304    0.234030  0.028383  30      384578     4
# 2018-10-24 18:05:23.769344000    0.250026  0.036141  30      384579     4
#
#                                    distance  rgt  n_fit_photons  \
# time
# 2018-10-24 18:05:23.758083840  7.708113e+06  399             45
# 2018-10-24 18:05:23.760899840  7.708133e+06  399             52
# 2018-10-24 18:05:23.763715840  7.708153e+06  399             48
# 2018-10-24 18:05:23.766530304  7.708173e+06  399             68
# 2018-10-24 18:05:23.769344000  7.708193e+06  399             50
#
#                                w_surface_window_final  \
# time
# 2018-10-24 18:05:23.758083840                     3.0
# 2018-10-24 18:05:23.760899840                     3.0
# 2018-10-24 18:05:23.763715840                     3.0
# 2018-10-24 18:05:23.766530304                     3.0
# 2018-10-24 18:05:23.769344000                     3.0
#
#                                                  geometry
# time
# 2018-10-24 18:05:23.758083840  POINT (-50.34127 69.11262)
# 2018-10-24 18:05:23.760899840  POINT (-50.34133 69.11279)
# 2018-10-24 18:05:23.763715840  POINT (-50.34139 69.11297)
# 2018-10-24 18:05:23.766530304  POINT (-50.34145 69.11315)
# 2018-10-24 18:05:23.769344000  POINT (-50.34151 69.11333)

# %%
#Remove outlier data
is2_df= is2_df[is2_df['h_mean'] < 175]
is2_df= is2_df[is2_df['h_mean'] > -75]

# %% [markdown]
# ## Visualize all of the ICESat-2 tracks since its launch within the region of interest

# %%
# # Visualize all of the ICESat-2 tracks since its launch within the region of interest

# # Calculate Extent
# lons = [p["lon"] for p in region]
# lats = [p["lat"] for p in region]
# lon_margin = (max(lons) - min(lons)) * 0.1
# lat_margin = (max(lats) - min(lats)) * 0.1

# # Create Plot
# fig, ax1 = plt.subplots(num=None, ncols=1, figsize=(12, 6))
# box_lon = [e["lon"] for e in region]
# box_lat = [e["lat"] for e in region]

# # Plot SlideRule Ground Tracks
# ax1.set_title("SlideRule Zoomed Ground Tracks")
# ROI = is2_df.plot(ax=ax1, column=is2_df["h_mean"], cmap='winter_r', s=1.0, zorder=3)
# ax1.plot(box_lon, box_lat, linewidth=1.5, color='r', zorder=2)
# ax1.set_xlim(min(lons) - lon_margin, max(lons) + lon_margin)
# ax1.set_ylim(min(lats) - lat_margin, max(lats) + lat_margin)
# ax1.set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Plot Time Series

# %%
# Add a date column to the data frame so we can group the data by day 

# get the timestamps from the dataframe index
timestamps = is2_df.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df['day'] = time

# %%
#%matplotlib widget
fig, ax = plt.subplots(figsize=(20, 6))

plt.plot(is2_df.groupby(['day']).mean()['h_mean'])

plt.xticks(rotation=45)

plt.show()
# Out:
# /tmp/ipykernel_3055/2184796724.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# # Create Regional Time Series for Fjord

# %% [markdown]
# ## East Region

# %%
# path to geoJSON polygon

# East Fjord
geoJSON_filepath = '/home/jovyan/hackweek2023/icemelange/data/gjsons/Jakobshavn_east.geojson'
region_ea = sliderule.toregion(geoJSON_filepath)["poly"]

print("East Polygon: ")
region_ea
# Out:
# East Polygon:
# [{'lon': -49.989773275146256, 'lat': 69.10200477899474},
#  {'lon': -49.90158875862826, 'lat': 69.10809774274587},
#  {'lon': -49.84117027276759, 'lat': 69.11599894849657},
#  {'lon': -49.79205503389916, 'lat': 69.13600213474544},
#  {'lon': -49.79174593359926, 'lat': 69.13870624159743},
#  {'lon': -49.78672414740628, 'lat': 69.19376869249525},
#  {'lon': -49.78877398600027, 'lat': 69.2024675890045},
#  {'lon': -49.796786456519094, 'lat': 69.20829362263899},
#  {'lon': -49.81101051505902, 'lat': 69.2162925752355},
#  {'lon': -50.13225888314705, 'lat': 69.21445631807542},
#  {'lon': -50.17265806975064, 'lat': 69.21282531891303},
#  {'lon': -50.20697408838873, 'lat': 69.20969529529557},
#  {'lon': -50.20594500512282, 'lat': 69.20568286621973},
#  {'lon': -50.192089853856494, 'lat': 69.17005925050293},
#  {'lon': -50.18586112928695, 'lat': 69.15677702804891},
#  {'lon': -50.010508466555606, 'lat': 69.10573723906185},
#  {'lon': -49.989773275146256, 'lat': 69.10200477899474}]

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region_ea,
    "srt": icesat2.SRT_SEA_ICE,
    "cnf": icesat2.CNF_SURFACE_HIGH,    
    "t0": "2018-12-01T00:00:00Z",  
    "t1": "2022-08-01T00:00:00Z", 
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df_ea = icesat2.atl06p(parms, "nsidc-s3")

# Print the head
is2_df_ea.head()    # Query returns no data
# Out:
# Empty GeoDataFrame
# Columns: [geometry]
# Index: []

# %%
# #Remove outlier data    
is2_df_ea = is2_df_ea[is2_df_ea['h_mean'] < 175]
is2_df_ea = is2_df_ea[is2_df_ea['h_mean'] > -75]

# %%
# Add a date column to the data frame so we can group the data by day 
# get the timestamps from the dataframe index
timestamps = is2_df_ea.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df_ea['day'] = time

# print the head of the data frame
is2_df_ea.head()

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.title("Jakobshavn Fjord: East Region")
plt.plot(is2_df_ea.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Center Region

# %%
# path to geoJSON polygon

# East Fjord
geoJSON_filepath = '/home/jovyan/hackweek2023/icemelange/data/gjsons/Jakobshavn_mid.geojson'
region_ce = sliderule.toregion(geoJSON_filepath)["poly"]

print("Center Polygon: ")
region_ce
# Out:
# Center Polygon:
# [{'lon': -50.52268667277289, 'lat': 69.12799535794046},
#  {'lon': -50.4159006861964, 'lat': 69.12826920366282},
#  {'lon': -50.269682636213254, 'lat': 69.13685284157046},
#  {'lon': -50.244026354810224, 'lat': 69.14005389024756},
#  {'lon': -50.205146130839864, 'lat': 69.15075914207608},
#  {'lon': -50.193030289148666, 'lat': 69.15519681821438},
#  {'lon': -50.20602440962679, 'lat': 69.19489189788993},
#  {'lon': -50.21432839774787, 'lat': 69.20507409846321},
#  {'lon': -50.220834170670855, 'lat': 69.20823452277214},
#  {'lon': -50.58184111126958, 'lat': 69.20926087844283},
#  {'lon': -50.673441144883405, 'lat': 69.20740368535955},
#  {'lon': -50.76123002594027, 'lat': 69.19213255719504},
#  {'lon': -50.78094807061578, 'lat': 69.18804949884753},
#  {'lon': -50.72876131151459, 'lat': 69.13424997330652},
#  {'lon': -50.689414409692105, 'lat': 69.12890545159506},
#  {'lon': -50.52268667277289, 'lat': 69.12799535794046}]

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region_ce,
    "srt": icesat2.SRT_SEA_ICE,
    "cnf": icesat2.CNF_SURFACE_HIGH,    
    "t0": "2018-12-01T00:00:00Z",    #t0: start time for filtering granules (format %Y-%m-%dT%H:%M:%SZ, e.g. 2018-10-13T00:00:00Z)
    "t1": "2022-08-01T00:00:00Z", 
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df_ce = icesat2.atl06p(parms, "nsidc-s3")

#is2_df_ce.head()

# %%
#Remove outlier data
is2_df_ce = is2_df_ce[is2_df_ce['h_mean'] < 175]
is2_df_ce = is2_df_ce[is2_df_ce['h_mean'] > -75]

# %%
# Add a date column to the data frame so we can group the data by day 
# get the timestamps from the dataframe index
timestamps = is2_df_ce.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df_ce['day'] = time

# print the head of the data frame
is2_df_ce.head()
# Out:
#                                   h_mean  dh_fit_dx  pflags  dh_fit_dy  cycle  \
# time
# 2018-12-18 04:11:01.958944256  25.255248   0.016131       0        0.0      1
# 2018-12-18 04:11:01.960346112  25.318524  -0.014712       0        0.0      1
# 2018-12-18 04:11:01.961751296  25.400285   0.037718       0        0.0      1
# 2018-12-18 04:11:01.963155456  26.136223   0.100518       0        0.0      1
# 2018-12-18 04:11:01.964559616  26.451815  -0.068647       0        0.0      1
#
#                                rms_misfit   h_sigma  gt  segment_id  spot  \
# time
# 2018-12-18 04:11:01.958944256    0.112246  0.112073  50      616905     2
# 2018-12-18 04:11:01.960346112    0.212449  0.042497  50      616905     2
# 2018-12-18 04:11:01.961751296    0.395414  0.074846  50      616906     2
# 2018-12-18 04:11:01.963155456    0.597651  0.107640  50      616906     2
# 2018-12-18 04:11:01.964559616    0.758499  0.118585  50      616907     2
#
#                                    distance   rgt  n_fit_photons  \
# time
# 2018-12-18 04:11:01.958944256  1.235633e+07  1230             13
# 2018-12-18 04:11:01.960346112  1.235634e+07  1230             28
# 2018-12-18 04:11:01.961751296  1.235635e+07  1230             28
# 2018-12-18 04:11:01.963155456  1.235636e+07  1230             33
# 2018-12-18 04:11:01.964559616  1.235637e+07  1230             41
#
#                                w_surface_window_final  \
# time
# 2018-12-18 04:11:01.958944256                3.000000
# 2018-12-18 04:11:01.960346112                3.000000
# 2018-12-18 04:11:01.961751296                3.000000
# 2018-12-18 04:11:01.963155456                4.553730
# 2018-12-18 04:11:01.964559616                4.890536
#
#                                                  geometry         day
# time
# 2018-12-18 04:11:01.958944256  POINT (-50.36662 69.17494)  2018-12-18
# 2018-12-18 04:11:01.960346112  POINT (-50.36665 69.17485)  2018-12-18
# 2018-12-18 04:11:01.961751296  POINT (-50.36668 69.17476)  2018-12-18
# 2018-12-18 04:11:01.963155456  POINT (-50.36671 69.17467)  2018-12-18
# 2018-12-18 04:11:01.964559616  POINT (-50.36674 69.17458)  2018-12-18

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.title("Jakobshavn Fjord: Middle Region")
plt.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_3055/4038345061.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# ## West Region

# %%
# path to geoJSON polygon

# East Fjord
geoJSON_filepath = '/home/jovyan/hackweek2023/icemelange/data/gjsons/Jakobshavn_west.geojson'
region_we = sliderule.toregion(geoJSON_filepath)["poly"]

print("West Polygon: ")
region_we
# Out:
# West Polygon:
# [{'lon': -50.93756706078053, 'lat': 69.12062339157777},
#  {'lon': -50.81636301612652, 'lat': 69.12667557985148},
#  {'lon': -50.801204764963416, 'lat': 69.12795382303807},
#  {'lon': -50.73594465283092, 'lat': 69.13554808360637},
#  {'lon': -50.736799954576924, 'lat': 69.14003277515364},
#  {'lon': -50.745848662459174, 'lat': 69.15471172484692},
#  {'lon': -50.754084491355634, 'lat': 69.16213682989415},
#  {'lon': -50.77877233377383, 'lat': 69.17989636608537},
#  {'lon': -50.790703937126544, 'lat': 69.18296289314115},
#  {'lon': -51.15064793209109, 'lat': 69.20120439226609},
#  {'lon': -51.161147654309275, 'lat': 69.20065612905515},
#  {'lon': -51.172161663652915, 'lat': 69.19775462036746},
#  {'lon': -51.18325690610557, 'lat': 69.18974618751375},
#  {'lon': -51.1831419904824, 'lat': 69.18129447853951},
#  {'lon': -51.17920494172613, 'lat': 69.16701301321055},
#  {'lon': -51.17487009831605, 'lat': 69.15814146989767},
#  {'lon': -51.149547444275804, 'lat': 69.1407479720041},
#  {'lon': -51.1315794764893, 'lat': 69.13677253859474},
#  {'lon': -50.95147418723264, 'lat': 69.1206896578055},
#  {'lon': -50.93756706078053, 'lat': 69.12062339157777}]

# %%
# Build SlideRule request
# Define parameters
parms = {
    "poly": region_we,
    "srt": icesat2.SRT_SEA_ICE,
    "cnf": icesat2.CNF_SURFACE_HIGH,    
    "t0": "2018-12-01T00:00:00Z",    #t0: start time for filtering granules (format %Y-%m-%dT%H:%M:%SZ, e.g. 2018-10-13T00:00:00Z)
    "t1": "2022-08-01T00:00:00Z", 
    "ats": 5.0,
    "len": 20.0,
    "res": 10.0,
    "maxi": 5
}

# Calculated ATL06 dataframe
is2_df_we = icesat2.atl06p(parms, "nsidc-s3")

is2_df_we.head()
# Out:
#                                   h_mean  dh_fit_dx  pflags  dh_fit_dy  cycle  \
# time
# 2018-12-22 04:02:42.638199808  22.654551   0.000928       0        0.0      1
# 2018-12-22 04:02:42.639608832  22.660474   0.004273       0        0.0      1
# 2018-12-22 04:02:42.641018880  22.681233   0.001230       0        0.0      1
# 2018-12-22 04:02:42.642427136  22.666682  -0.004694       0        0.0      1
# 2018-12-22 04:02:42.643838464  22.642241  -0.001241       0        0.0      1
#
#                                rms_misfit   h_sigma  gt  segment_id  spot  \
# time
# 2018-12-22 04:02:42.638199808    0.068888  0.047941  50      616761     2
# 2018-12-22 04:02:42.639608832    0.107831  0.015122  50      616761     2
# 2018-12-22 04:02:42.641018880    0.115359  0.010665  50      616762     2
# 2018-12-22 04:02:42.642427136    0.140303  0.012922  50      616762     2
# 2018-12-22 04:02:42.643838464    0.146206  0.013405  50      616763     2
#
#                                    distance   rgt  n_fit_photons  \
# time
# 2018-12-22 04:02:42.638199808  1.235349e+07  1291             19
# 2018-12-22 04:02:42.639608832  1.235350e+07  1291             78
# 2018-12-22 04:02:42.641018880  1.235351e+07  1291            117
# 2018-12-22 04:02:42.642427136  1.235352e+07  1291            118
# 2018-12-22 04:02:42.643838464  1.235353e+07  1291            119
#
#                                w_surface_window_final  \
# time
# 2018-12-22 04:02:42.638199808                     3.0
# 2018-12-22 04:02:42.639608832                     3.0
# 2018-12-22 04:02:42.641018880                     3.0
# 2018-12-22 04:02:42.642427136                     3.0
# 2018-12-22 04:02:42.643838464                     3.0
#
#                                                  geometry
# time
# 2018-12-22 04:02:42.638199808  POINT (-51.13692 69.20020)
# 2018-12-22 04:02:42.639608832  POINT (-51.13695 69.20011)
# 2018-12-22 04:02:42.641018880  POINT (-51.13698 69.20002)
# 2018-12-22 04:02:42.642427136  POINT (-51.13701 69.19993)
# 2018-12-22 04:02:42.643838464  POINT (-51.13704 69.19984)

# %%
#Remove outlier data
is2_df_we = is2_df_we[is2_df_we['h_mean'] < 175]
is2_df_we = is2_df_we[is2_df_we['h_mean'] > -75]

# %%
# Add a date column to the data frame so we can group the data by day 
# get the timestamps from the dataframe index
timestamps = is2_df_we.index.tolist()

# get the YYYY-MM-DD for each row
time = []
for t in timestamps:
    time.append(str(t)[0:10])
    
# store YYYY-MM-DD in a new column called day
is2_df_we['day'] = time

# %%
# Plot the timeseries 
fig, ax = plt.subplots(figsize=(20, 6))
plt.title("Jakobshavn Fjord: West Region")
plt.plot(is2_df_we.groupby(['day']).mean()['h_mean'])
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_3055/3538155721.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.plot(is2_df_we.groupby(['day']).mean()['h_mean'])

# %% [markdown]
# ### Plot the time series
#
# Sea ice height from ellipsoid

# %%
#fig,(ax1,ax2,ax3) = plt.subplots(3,figsize=(20, 18))
fig,(ax1,ax2) = plt.subplots(2,figsize=(20, 18))

ax1.plot(is2_df_we.groupby(['day']).mean()['h_mean'])
ax1.set_title("West")
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
ax1.set_ylim(20,45)

ax2.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])
ax2.set_title("Center")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')
ax2.set_ylim(20,45)

# ax3.plot(is2_df_ea.groupby(['day']).mean()['h_mean'])
# ax3.set_title("East")
# ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45, ha='right')
# ax3.set_ylim(20,45)

plt.show()
# Out:
# /tmp/ipykernel_3055/684000885.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax1.plot(is2_df_we.groupby(['day']).mean()['h_mean'])
# /tmp/ipykernel_3055/684000885.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
# /tmp/ipykernel_3055/684000885.py:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax2.plot(is2_df_ce.groupby(['day']).mean()['h_mean'])
# /tmp/ipykernel_3055/684000885.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# ## Height correction
# Work in progress...

# %%
geoid_ht = pd.read_csv('../data/geoid_height_2023-08-10.csv')

# %%
is2_df_ce['lon'] = is2_df_ce['geometry'].geometry.x
is2_df_ce['lat'] = is2_df_ce['geometry'].geometry.y

# %%
# Method to store the tide 
# %pip install pickle
import pickle

with open("tide.pickle", "wb") as f:
    pickle.dump(tide, f)
    
dbfile = open('tidePickle', 'ab')
     
# source, destination
pickle.dump(tide, dbfile)                   
dbfile.close()

# %%
# Calculate geoid height for df

epsilon = .00001

h_real = []

for i in range(50):
    lon = is2_df_ce['lon'][i]
    lat = is2_df_ce['lat'][i]
    geoid = (geoid_ht.loc[(geoid_ht['Longitude'] >= (lon-epsilon)) & (geoid_ht['Longitude'] <= (lon+epsilon)) 
            & (geoid_ht['Latitude'] >= (lat-epsilon)) & (geoid_ht['Latitude'] <= (lat+epsilon))]['Geoid Height (m)'])
    # print(is2_df_ce['h_mean'][i])
    # print(geoid)
    # print(is2_df_ce['h_mean'][i] - geoid) 
    # print()

# %%
# Tide data - WIP

# from pyproj import Proj, transform

xs = is2_df_ce['lon'][0:1000]
ys = is2_df_ce['lat'][0:1000]
#timestamps = is2_df_ce.index.tolist()

timeStamps = np.array(is2_df_ce.index.tolist(), dtype=np.datetime64)

from pyTMD.compute_tide_corrections import compute_tide_corrections

tide = compute_tide_corrections(xs, ys, timeStamps,
    MODEL= 'AODTM-5', TIME='datetime', EPSG=4326, TYPE='time series')
